# %%
# %autoreload 2
from loader import Loader 
from model import StockModel
from plot import Plot

# Set stock symbol
stock = 'PFE'

# Load and prepare data
loader = Loader()

# Create and save model
model = StockModel(loader.get_stock_data(stock))
model.train_model()
model.toFile()
# Out:
# Epoch 1/100
# 47/47 - 3s - 54ms/step - loss: 0.2896 - metric_mse_for_feature: 0.1445 - metric_r2score: -1.6400e+00 - metric_rmse_for_feature: 0.3508 - metric_smape: 82.8231 - mse: 0.1339 - val_loss: 0.1328 - val_metric_mse_for_feature: 0.0117 - val_metric_r2score: -6.7162e-01 - val_metric_rmse_for_feature: 0.1060 - val_metric_smape: 57.1399 - val_mse: 0.0321
# Epoch 2/100
# 47/47 - 1s - 13ms/step - loss: 0.1388 - metric_mse_for_feature: 0.0280 - metric_r2score: 0.3589 - metric_rmse_for_feature: 0.1658 - metric_smape: 35.6834 - mse: 0.0325 - val_loss: 0.1065 - val_metric_mse_for_feature: 0.0061 - val_metric_r2score: -3.5862e-01 - val_metric_rmse_for_feature: 0.0745 - val_metric_smape: 46.4846 - val_mse: 0.0263
# Epoch 3/100
# 47/47 - 1s - 15ms/step - loss: 0.1043 - metric_mse_for_feature: 0.0152 - metric_r2score: 0.6308 - metric_rmse_for_feature: 0.1228 - metric_smape: 27.2046 - mse: 0.0186 - val_loss: 0.1062 - val_metric_mse_for_feature: 0.0054 - val_metric_r2score: -1.5438e-02 - val_metric_rmse_for_feature: 0.0688 - val_metric_smape: 46.0016 - val_mse: 0.0194
# Epoch 4/100
# 47/47 - 1s - 14ms/step - loss: 0.0878 - metric_mse_for_feature: 0.0119 - metric_r2score: 0.7382 - metric_rmse_for_feature: 0.1090 - metric_smape: 22.9873 - mse: 0.0131 - val_loss: 0.0937 - val_metric_mse_for_feature: 0.0057 - val_metric_r2score: 0.1631 - val_metric_rmse_for_feature: 0.0696 - val_metric_smape: 42.4285 - val_mse: 0.0160
# Epoch 5/100
# 47/47 - 1s - 14ms/step - loss: 0.0787 - metric_mse_for_feature: 0.0104 - metric_r2score: 0.7888 - metric_rmse_for_feature: 0.1016 - metric_smape: 20.2532 - mse: 0.0106 - val_loss: 0.0957 - val_metric_mse_for_feature: 0.0067 - val_metric_r2score: 0.2153 - val_metric_rmse_for_feature: 0.0751 - val_metric_smape: 43.4233 - val_mse: 0.0149
# Epoch 6/100
# 47/47 - 1s - 14ms/step - loss: 0.0723 - metric_mse_for_feature: 0.0091 - metric_r2score: 0.8205 - metric_rmse_for_feature: 0.0953 - metric_smape: 18.5906 - mse: 0.0090 - val_loss: 0.0973 - val_metric_mse_for_feature: 0.0078 - val_metric_r2score: 0.2027 - val_metric_rmse_for_feature: 0.0805 - val_metric_smape: 43.8581 - val_mse: 0.0151
# Epoch 7/100
# 47/47 - 1s - 16ms/step - loss: 0.0670 - metric_mse_for_feature: 0.0080 - metric_r2score: 0.8434 - metric_rmse_for_feature: 0.0890 - metric_smape: 17.0625 - mse: 0.0078 - val_loss: 0.0997 - val_metric_mse_for_feature: 0.0089 - val_metric_r2score: 0.1673 - val_metric_rmse_for_feature: 0.0850 - val_metric_smape: 44.5667 - val_mse: 0.0157
# Epoch 8/100
# 47/47 - 1s - 16ms/step - loss: 0.0633 - metric_mse_for_feature: 0.0073 - metric_r2score: 0.8613 - metric_rmse_for_feature: 0.0853 - metric_smape: 16.0077 - mse: 0.0070 - val_loss: 0.1074 - val_metric_mse_for_feature: 0.0112 - val_metric_r2score: 0.0917 - val_metric_rmse_for_feature: 0.0959 - val_metric_smape: 46.7875 - val_mse: 0.0171
# Epoch 9/100
# 47/47 - 1s - 14ms/step - loss: 0.0596 - metric_mse_for_feature: 0.0065 - metric_r2score: 0.8753 - metric_rmse_for_feature: 0.0807 - metric_smape: 15.0610 - mse: 0.0063 - val_loss: 0.1092 - val_metric_mse_for_feature: 0.0115 - val_metric_r2score: 0.0561 - val_metric_rmse_for_feature: 0.0962 - val_metric_smape: 47.2342 - val_mse: 0.0177
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
from lib_types import DateRange

range: DateRange = ("2024-10-01", None)

stock = loader.get_stock(stock)
plot = Plot(stock, range)
plot.draw()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
