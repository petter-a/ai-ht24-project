# %%
# %autoreload 2
from loader import Loader 
from model import StockModel
from plot import Plot

# Set stock symbol
stock = 'MMM'

# Load and prepare data
loader = Loader()

# Create and save model
model = StockModel(loader.get_stock_data(stock))
model.train_model()
model.toFile()
# Out:
#          Adj Close        Close         High          Low         Open  \
# count  3732.000000  3732.000000  3732.000000  3732.000000  3732.000000
# mean     27.492612    31.719843    32.007593    31.429557    31.718941
# std      10.859069     9.054312     9.168137     8.931110     9.049985
# min       8.679071    13.415560    13.595825    13.282732    13.491461
# 25%      20.316312    27.246205    27.465095    27.051709    27.239772
# 50%      26.779205    31.655598    31.869070    31.413662    31.660341
# 75%      34.284351    36.381301    36.692072    36.083965    36.406547
# max      60.787823    61.250000    61.709999    59.830002    60.599998
#
#              Volume      SMA_low     SMA_high      EMA_low     EMA_high
# count  3.732000e+03  3732.000000  3732.000000  3732.000000  3732.000000
# mean   3.326659e+07    31.714002    31.707104    31.703853    31.682992
# std    2.019676e+07     9.049915     9.045348     9.031368     9.008144
# min    5.187683e+06    13.510436    13.688805    13.783736    14.013463
# 25%    2.113811e+07    27.274668    27.255567    27.283936    27.343455
# 50%    2.772210e+07    31.634725    31.628568    31.624105    31.605014
# 75%    3.870860e+07    36.307550    36.326376    36.270843    36.253124
# max    2.998294e+08    60.050000    59.255000    58.063755    56.008530
# Symbol       0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# SMA_low      0
# SMA_high     0
# EMA_low      0
# EMA_high     0
# dtype: int64
# /Users/pean1022/github/ai-ht24-project/src/loader.py:43: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[column] = data[column].fillna(method='bfill')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 14
#      12 # Create and save model
#      13 model = StockModel(loader.get_stock_data(stock))
# ---> 14 model.train_model()
#      15 model.toFile()
#
# File ~/github/ai-ht24-project/src/model.py:118, in StockModel.train_model(self)
#     113 y_train, y_val = y[:size], y[size:]
#     115 # ====================================================
#     116 # Compile model
#     117 # ====================================================
# --> 118 self.model = self.create_model()
#     120 # ====================================================
#     121 # Create stopping function to avoid overfitting
#     122 # ====================================================
#     123 early_stopping = EarlyStopping(
#     124     monitor='val_loss',
#     125     patience=10,
#     126     restore_best_weights=True)
#
# File ~/github/ai-ht24-project/src/model.py:162, in StockModel.create_model(self)
#     159 def create_model(self) -> Sequential:
#     160     features = len(self.dataset.columns)
# --> 162     model = Sequential([
#     163         Input(shape=(self.steps, features)),
#     164         LSTM(self.units, activation='relu', return_sequences=True),
#     165         Dropout(0.2),
#     166         LSTM(self.units, activation='relu', return_sequences=False),
#     167         Dropout(0.2),
#     168         LSTM(self.units, activation='relu', return_sequences=True),
#     169         Dropout(0.2),
#     170         RepeatVector(self.horizon),
#     171         TimeDistributed(Dense(features))
#     172     ])
#     173     model.compile(optimizer=Adam(learning_rate=self.learning_rate),
#     174         loss='mae',
#     175         metrics=[
#    (...)
#     179             metric_smape,
#     180             metric_r2score])
#     181     return model
#
# File ~/github/ai-ht24-project/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:76, in Sequential.__init__(self, layers, trainable, name)
#      74 for layer in layers:
#      75     self.add(layer, rebuild=False)
# ---> 76 self._maybe_rebuild()
#
# File ~/github/ai-ht24-project/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:141, in Sequential._maybe_rebuild(self)
#     139 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     140     input_shape = self._layers[0].batch_shape
# --> 141     self.build(input_shape)
#     142 elif hasattr(self._layers[0], "input_shape") and len(self._layers) > 1:
#     143     # We can build the Sequential model if the first layer has the
#     144     # `input_shape` property. This is most commonly found in Functional
#     145     # model.
#     146     input_shape = self._layers[0].input_shape
#
# File ~/github/ai-ht24-project/.venv/lib/python3.12/site-packages/keras/src/layers/layer.py:226, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     224 with obj._open_name_scope():
#     225     obj._path = current_path()
# --> 226     original_build_method(*args, **kwargs)
#     227 # Record build config.
#     228 signature = inspect.signature(original_build_method)
#
# File ~/github/ai-ht24-project/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:187, in Sequential.build(self, input_shape)
#     185 for layer in self._layers[1:]:
#     186     try:
# --> 187         x = layer(x)
#     188     except NotImplementedError:
#     189         # Can happen if shape inference is not implemented.
#     190         # TODO: consider reverting inbound nodes on layers processed.
#     191         return
#
# File ~/github/ai-ht24-project/.venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/github/ai-ht24-project/.venv/lib/python3.12/site-packages/keras/src/layers/input_spec.py:186, in assert_input_compatibility(input_spec, inputs, layer_name)
#     184 if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#     185     if ndim != spec.ndim:
# --> 186         raise ValueError(
#     187             f'Input {input_index} of layer "{layer_name}" '
#     188             "is incompatible with the layer: "
#     189             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     190             f"Full shape received: {shape}"
#     191         )
#     192 if spec.max_ndim is not None:
#     193     if ndim is not None and ndim > spec.max_ndim:
#
# ValueError: Input 0 of layer "lstm_123" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 64)

# %%
from lib_types import DateRange

range: DateRange = ("2024-10-01", None)

stock = loader.get_stock(stock)
plot = Plot(stock, range)
plot.draw()
# Out:
# /Users/pean1022/github/ai-ht24-project/src/loader.py:43: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[column] = data[column].fillna(method='bfill')
#          Adj Close        Close         High          Low         Open  \
# count  3732.000000  3732.000000  3732.000000  3732.000000  3732.000000
# mean     27.492612    31.719843    32.007593    31.429557    31.718941
# std      10.859069     9.054312     9.168137     8.931110     9.049985
# min       8.679071    13.415560    13.595825    13.282732    13.491461
# 25%      20.316312    27.246205    27.465095    27.051709    27.239772
# 50%      26.779205    31.655598    31.869070    31.413662    31.660341
# 75%      34.284351    36.381301    36.692072    36.083965    36.406547
# max      60.787823    61.250000    61.709999    59.830002    60.599998
#
#              Volume      SMA_low     SMA_high      EMA_low     EMA_high
# count  3.732000e+03  3732.000000  3732.000000  3732.000000  3732.000000
# mean   3.326659e+07    31.714002    31.707104    31.703853    31.682992
# std    2.019676e+07     9.049915     9.045348     9.031368     9.008144
# min    5.187683e+06    13.510436    13.688805    13.783736    14.013463
# 25%    2.113811e+07    27.274668    27.255567    27.283936    27.343455
# 50%    2.772210e+07    31.634725    31.628568    31.624105    31.605014
# 75%    3.870860e+07    36.307550    36.326376    36.270843    36.253124
# max    2.998294e+08    60.050000    59.255000    58.063755    56.008530
# Symbol       0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# SMA_low      0
# SMA_high     0
# EMA_low      0
# EMA_high     0
# dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
